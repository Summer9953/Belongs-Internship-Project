# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ahsan\Output.csv")
df
# Out:
#                                                     0  \
# 0   {'_id': '61d82dc0516ff700231e3e90', 'roles': [...
# 1   {'_id': '626e4a6e2b814c00160b3809', 'appliedOn...
# 2   {'_id': '62f4350e3f852a0016a5f972', 'responses...
# 3   {'_id': '60bf4ccd63dbccf5133ea70d', 'title': '...
# 4   {'_id': '625ffbb750a629272b538a87', 'title': '...
# 5   {'_id': '60c08e17c00413002243cf33', 'acceptedF...
# 6   {'_id': '62a9722d04885c2b744a3751', 'type': '2...
# 7   {'_id': '60b88d6569a1e0002266eb89', 'name': 'M...
# 8   {'_id': '631b1f81fe71aa00161ae1d1', 'skillId':...
# 9   {'_id': '606b0ffeb689e8771091c66d', 'title': '...
# 10  {'_id': '60b88a4969a1e0002266eb88', 'areas': [...
# 11  {'_id': '60b8883a69a1e0002266eb86', 'areas': [...
# 12  {'_id': '618bc741b88ec20023aed9e8', 'program':...
# 13  {'_id': '62fa4cb9caa6640016d848b7', 'skills': ...
# 14                                                NaN
# 15  {'_id': '60a7fbfbfa2f8d0022e3643d', 'status': ...
# ...

# %%
df=df.T
df
# Out:
#                                                       0   \
# 0      {'_id': '61d82dc0516ff700231e3e90', 'roles': [...
# 1      {'_id': '61d82fa2516ff700231e3edc', 'roles': [...
# 2      {'_id': '61d83043516ff700231e3ee1', 'roles': [...
# 3      {'_id': '61d83063516ff700231e3ee9', 'roles': [...
# 4      {'_id': '61e120e5945b220023502bd5', 'roles': [...
# ...                                                  ...
# 13075                                                NaN
# 13076                                                NaN
# 13077                                                NaN
# 13078                                                NaN
# 13079                                                NaN
#
#                                                       1   \
# 0      {'_id': '626e4a6e2b814c00160b3809', 'appliedOn...
# 1      {'_id': '627511a376a6e60016707cf6', 'appliedOn...
# 2      {'_id': '627511af76a6e60016707d0a', 'appliedOn...
# ...
